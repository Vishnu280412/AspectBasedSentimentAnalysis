# %% [markdown]
# <a href="https://colab.research.google.com/github/aditya-unni/SET1/blob/main/webscrapper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

url = 'https://www.tripadvisor.in/AttractionProductReview-g304554-d16731994-Mumbai_Temple_Tour_in_Private_Vehicle-Mumbai_Maharashtra.html'
response = requests.get(url)
print(response)
if response.status_code == 200:
    # Proceed with parsing the HTML content
    print("gay1")
    page_content = response.text
else:
    print(f"Request failed with status code: {response.status_code}")
# Out:
# <Response [403]>
# Request failed with status code: 403

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(page_content, 'html.parser')
# Use soup.select or soup.find to locate specific elements
reviews = soup.select('.yCeTE')  # Example selector for review text

# %%
for review in reviews:
    review_text = review.get_text()
    print(review_text)
# Out:
# Most Recent: Reviews ordered by most recent publish date in descending order.
#  Detailed Reviews: Reviews ordered by recency and descriptiveness of user-identified themes such as waiting time, length of visit, general tips, and location information.
# An in-depth experience
# Vikrant our tour guide was amazing, very friendly, knowledgeable, and certainly knows his way around the city’s temples! Vikrant provided us with a driver as well, so parking was never an issue. We got VIP access to the temples, so there was not much waiting, even though it was the first day of the year (a very busy day for temples). Please be aware though that you do have to take your shoes off when visiting temples, so your feet will become quite dirty, so bring plenty of wet wipes or bring shoes whose soles you don’t mind getting dirty. Also keep in mind this is an intense experience that easily takes half a day since you’re visiting multiple temples.
# Best way to start a visit to Mumbai
# This trip has 5 star reviews and I can see why. Sameer the owner puts so much heart and soul in the work that he does. He kept in touch with me before the tour began, and was early at my pick up point which gave me great comfort. He really tailored the tour based on what I wanted, and I felt very valued. He treats you with respect and you don't feel rushed anywhere. He runs these tours with great ethic, and he has attention to detail, and you really feel like you are being cared for. I wish Sameer and this team the very best and I would recommend this company to anyone.
# Everything is comfortable with meticulous care
# It was discovered that we had been double booked by mistake...Still, he explained it carefully without being nasty and dealt with the other case precisely.They responded immediately to our request and the advice at key points was very reassuring.They even took care when getting on and off the car, making everything a comfortable sightseeing experience. Thanks to Samir's meticulous care, I really enjoyed participating.Samir, thank you so much.
# Hitomi
# Really enjoyed this tour as the tour guide was so nice, kind and has a wealth of knowledge about not only temple and gods but religion, culture and history of India.When we had a sudden heavy rain, he flexibly arranged another plan not to waste my time.It’s my first trip to India and I was a little bit nervous but his warm hospitality made me relaxed and enjoyable.
# A thoroughly enjoyable temple tour.
# I had a really interesting tour of the temples. Vikrant was knowledgeable and friendly, with excellent local knowledge. Sometimes these tours can be a case of information overload but Vikrant has pitched it just right. You won’t regret booking this tour. Would 100% recommend.
# temple tour
# Sameer, the owner was excellent and we felt very safe with his driver.  We are both Christians and loved learning about the temples and different religions in Mumbai. You can also tell Sameer loves his job and educating people about his home city.Good Luck to you and your tour company.
# Trustworthy and reliability and caring
# Sameer explained everything to me about temples and he was very patient, open, and reliable. He cares about his work and I enjoyed the places he showed to me. He is also very flexible. I recommend his tour to everyone who would like to get a tour. It is private tour and it has flexibility, reliability, care and attention.
# I would do this again and agian
# Awesome experience. Sameer is an amazing guide very informative and knowledgeable and super easy going. We had some good laughs. Loved visiting the temples and learning about the different religions in Mumbai and especially demystifying the Hindu religion.
# Ganesh Chaturati Fest & Ashtavinayak Tour
# Well made decision choosing Shreeji Tour for car hire n driver Mumbai-Pune-Mumbai. Vikrant responses to inquiries fast and guided me to famous temples which I enjoy so much in cultural experiences. Naeem the driver, a calm and discreet person drove us through the entire itinerary (11 hrs. driving), I felt safe n comfy in a new car per my request. Price is friendly as i compared 4 companies before making decision.My first time Mumbai is memorable.Highly recommend
# Excellent choice to experience temple visit like a local!
# The "Temple Tour" of Mumbai with Shreeji Tours and Travels was awesome and definitely an excellent choice to experience temple visit like a local! The tour was as well a great insight of the variety of religious practices which Mumbai, and India in general, has to offer.With the tour guide Sameer and the driver, both super nice and kind, we visited Iskcon Juhu, Mahalaxmi Temple, Babulnath Temple, Banganga, Haji Ali Mosque, a church, a Jain Temple... to mention just a few!The tour guide Sameer is very knowledgeable and provided a lot of information about different religious practices and beliefs with a local touch. I highly recommend this tour since you will learn a lot and understand the spirituality of India with new perspectives!

# %%
# Fullproof code to collect reviews and user data from TripAdvisor

import sys
import csv
from selenium import webdriver
# from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoSuchElementException
import time

#User Details
profiles_list=[]
combined_data_list = []

# default path to file to store data
path_to_file = "reviews.csv"

# default number of scraped pages
# num_page = 700
num_page = 2

# default tripadvisor website of hotel or things to do (attraction/monument)
# url = "https://www.tripadvisor.in/AttractionProductReview-g304554-d16796488-Private_Full_Day_Mumbai_Sightseeing_Tour_with_Dharavi_Slums-Mumbai_Maharashtra.html"
url = "https://www.tripadvisor.in/Attraction_Review-g304554-d321437-Reviews-Marine_Drive-Mumbai_Maharashtra.html"

# if you pass the inputs in the command line
if (len(sys.argv) == 4):
    path_to_file = sys.argv[1]
    num_page = int(sys.argv[2])
    url = sys.argv[3]

# import the webdriver
driver = webdriver.Chrome()
driver.maximize_window()
driver.get(url)

# open the file to save the review
csvFile = open(path_to_file, 'a', encoding="utf-8")
csvWriter = csv.writer(csvFile)

column_headings = ["Date", "Title", "Review", "Name", "Username", "Loaction", "Joined_Date"]
csvWriter.writerow(column_headings)

# change the value inside the range to save more or less reviews
for i in range(0, num_page):

    # expand the review
    time.sleep(2)

    container = driver.find_elements("xpath","//div[contains(@data-automation, 'reviewCard')]")
    dates = driver.find_elements("xpath","//div[@class='biGQs _P pZUbB ncFvv osNWb']")

    for j in range(len(container)):
        button = container[j].find_element("xpath", ".//button//span[text()='Read more']/..")
        if button.is_displayed() and button.is_enabled():
            button.click()
        title = container[j].find_element("xpath",".//div[@class='biGQs _P fiohW qWPrE ncFvv fOtGX']/a/span").text
        review = container[j].find_element("xpath",".//div[@class='biGQs _P pZUbB KxBGd']/span[@class='yCeTE']").text.replace("\n", "  ")

        profile_link = container[j].find_element("xpath", ".//a[contains(@class, 'BMQDV')]").get_attribute("href")
        profiles_list.append(profile_link)

        if len(dates) > j:
            date = " ".join(dates[j].text.split(" ")[-2:])
        else:
            date = "Date Not Available"

#         date = " ".join(dates[j].text.split(" ")[-2:])
#         csvWriter.writerow([date, title, review])
        combined_data = {
            "Date": date,
            "Title": title,
            "Review": review,
            "Name": "",
            "Username": "",
            "Location": "",
            "Joined_Date": ""
        }
        combined_data_list.append(combined_data)

    # change the page
    try:
        nextbutton=driver.find_element("xpath",".//a[contains(@data-smoke-attr,'pagination-next-arrow')]")
        if nextbutton.is_displayed() and nextbutton.is_enabled():
            nextbutton.click()
        else:
            print("Reached the last page.")
            break
    except NoSuchElementException:
        print("Pagination element not found. Reached the last page.")
        break


iteration = 1

for profile_url in profiles_list:

    driver.get(profile_url)
    time.sleep(2)

    intro = driver.find_element("xpath", "//div[contains(@class, 'Me Nb MD NC')]")

    try:
        loc = intro.find_element("xpath", ".//span[@class='PacFI _R S4 H3 LXUOn default']").text
    except NoSuchElementException:
        loc = "Location Not Available"

    try:
        joined = intro.find_element("xpath", ".//span[@class='ECVao _R H3']").text
    except NoSuchElementException:
        joined = "Joined Date Not Available"

    user_info = driver.find_element("xpath", "//span[@class='ecLBS _R shSnD']")

    try:
        username = user_info.find_element("xpath", ".//span[@class='Dsdjn _R']").text
    except NoSuchElementException:
        username = "Username Not Available"

    try:
        name = user_info.find_elements("xpath", ".//span[@class='JWmxy']/h1/span[@class='OUDwj b brsfY']")[0].text
    except (IndexError, NoSuchElementException):
        name = "Name Not Available"

#     print("For iteration ", iteration, ": ", "name, username, joined, loc: \n", name, "\n", username, "\n", joined, "\n", loc, "\n")
#     csvWriter.writerow(["", "", "", name, username, loc, joined])
    combined_data = combined_data_list[iteration - 1]
    combined_data["Name"] = name
    combined_data["Username"] = username
    combined_data["Location"] = loc
    combined_data["Joined_Date"] = joined

    iteration+=1

for data in combined_data_list:
    csvWriter.writerow([data["Date"], data["Title"], data["Review"], data["Name"], data["Username"], data["Location"], data["Joined_Date"]])

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[13], line 57
#      55     button.click()
#      56 title = container[j].find_element("xpath",".//div[@class='biGQs _P fiohW qWPrE ncFvv fOtGX']/a/span").text
# ---> 57 review = container[j].find_element("xpath",".//div[@class='biGQs _P pZUbB KxBGd']/span[@class='yCeTE']").text.replace("\n", "  ")
#      59 profile_link = container[j].find_element("xpath", ".//a[contains(@class, 'BMQDV')]").get_attribute("href")
#      60 profiles_list.append(profile_link)
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/webelement.py:417, in WebElement.find_element(self, by, value)
#     414     by = By.CSS_SELECTOR
#     415     value = f'[name="{value}"]'
# --> 417 return self._execute(Command.FIND_CHILD_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/webelement.py:395, in WebElement._execute(self, command, params)
#     393     params = {}
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":".//div[@class='biGQs _P pZUbB KxBGd']/span[@class='yCeTE']"}
#   (Session info: chrome=129.0.6668.90); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x0000000105044248 cxxbridge1$str$ptr + 1907280
# 1   chromedriver                        0x000000010503c730 cxxbridge1$str$ptr + 1875768
# 2   chromedriver                        0x0000000104c50260 cxxbridge1$string$len + 89488
# 3   chromedriver                        0x0000000104c9450c cxxbridge1$string$len + 368700
# 4   chromedriver                        0x0000000104c8aad0 cxxbridge1$string$len + 329216
# 5   chromedriver                        0x0000000104cce7d0 cxxbridge1$string$len + 606976
# 6   chromedriver                        0x0000000104c8912c cxxbridge1$string$len + 322652
# 7   chromedriver                        0x0000000104c89d7c cxxbridge1$string$len + 325804
# 8   chromedriver                        0x000000010500c4d8 cxxbridge1$str$ptr + 1678560
# 9   chromedriver                        0x0000000105010e40 cxxbridge1$str$ptr + 1697352
# 10  chromedriver                        0x0000000104ff15ec cxxbridge1$str$ptr + 1568244
# 11  chromedriver                        0x0000000105011710 cxxbridge1$str$ptr + 1699608
# 12  chromedriver                        0x0000000104fe2b90 cxxbridge1$str$ptr + 1508248
# 13  chromedriver                        0x000000010502d828 cxxbridge1$str$ptr + 1814576
# 14  chromedriver                        0x000000010502d980 cxxbridge1$str$ptr + 1814920
# 15  chromedriver                        0x000000010503c3d0 cxxbridge1$str$ptr + 1874904
# 16  libsystem_pthread.dylib             0x00000001955cb2e4 _pthread_start + 136
# 17  libsystem_pthread.dylib             0x00000001955c60fc thread_start + 8

# %%
# Fullproof code to collect reviews and user data from TripAdvisor of multiplePlaces

import sys
import csv
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import time
import multiprocessing


def scrape_and_append_reviews(url, destination_code):
    #User Details
    profiles_list=[]
    combined_data_list = []

    # default number of scraped pages
    num_page = 50

    # default path to file to store data
    path_to_file = "C:\\Users\\vishn\\Desktop\\SET1\\reviews_" + destination_code + ".csv"

    # open the file to save the review
    csvFile = open(path_to_file, 'a', encoding="utf-8")
    csvWriter = csv.writer(csvFile)

    column_headings = ["Date", "Title", "Review", "Destination_ID", "Name", "Username", "Location", "Joined_Date"]
    csvWriter.writerow(column_headings)

    # import the webdriver
    driver = webdriver.Chrome(options=webdriver.ChromeOptions().add_argument('--headless'))
    driver.maximize_window()
    driver.get(url)

    # change the value inside the range to save more or less reviews
    for i in range(0, num_page):

        # expand the review
        time.sleep(2)

        container = driver.find_elements("xpath","//div[contains(@data-automation, 'reviewCard')]")
        dates = driver.find_elements("xpath","//div[@class='biGQs _P pZUbB ncFvv osNWb']")

        for j in range(len(container)):
            button = container[j].find_element("xpath", ".//button//span[text()='Read more']/..")
            if button.is_displayed() and button.is_enabled():
                button.click()
            title = container[j].find_element("xpath",".//div[@class='biGQs _P fiohW qWPrE ncFvv fOtGX']/a/span").text
            review = container[j].find_element("xpath",".//div[@class='biGQs _P pZUbB KxBGd']/span[@class='yCeTE']").text.replace("\n", "  ")

            profile_link = container[j].find_element("xpath", ".//a[contains(@class, 'BMQDV')]").get_attribute("href")
            profiles_list.append(profile_link)

            if len(dates) > j:
                date = " ".join(dates[j].text.split(" ")[-2:])
            else:
                date = "Date Not Available"

            combined_data = {
                "Date": date,
                "Title": title,
                "Review": review,
                "Destination_ID": destination_code,
                "Name": "",
                "Username": "",
                "Location": "",
                "Joined_Date": ""

            }
            combined_data_list.append(combined_data)


        # change the page
        try:
            nextbutton=driver.find_element("xpath",".//a[contains(@data-smoke-attr,'pagination-next-arrow')]")
            if nextbutton.is_displayed() and nextbutton.is_enabled():
                nextbutton.click()
            else:
                print("Reached the last page.")
                break
        except NoSuchElementException:
            print("Pagination element not found. Reached the last page.")
            break


    iteration = 0

    for profile_url in profiles_list:

        driver.get(profile_url)
        time.sleep(2)

        intro = driver.find_element("xpath", "//div[contains(@class, 'Me Nb MD NC')]")

        try:
            loc = intro.find_element("xpath", ".//span[@class='PacFI _R S4 H3 LXUOn default']").text
        except NoSuchElementException:
            loc = "Location Not Available"

        try:
            joined = intro.find_element("xpath", ".//span[@class='ECVao _R H3']").text
        except NoSuchElementException:
            joined = "Joined Date Not Available"

        user_info = driver.find_element("xpath", "//span[@class='ecLBS _R shSnD']")

        try:
            username = user_info.find_element("xpath", ".//span[@class='Dsdjn _R']").text
        except NoSuchElementException:
            username = "Username Not Available"

        try:
            name = user_info.find_elements("xpath", ".//span[@class='JWmxy']/h1/span[@class='OUDwj b brsfY']")[0].text
        except (IndexError, NoSuchElementException):
            name = "Name Not Available"

        combined_data = combined_data_list[iteration - 1]
        combined_data["Name"] = name
        combined_data["Username"] = username
        combined_data["Location"] = loc
        combined_data["Joined_Date"] = joined

        iteration+=1

    for data in combined_data_list:
        csvWriter.writerow([data["Date"], data["Title"], data["Review"], data["Destination_ID"], data["Name"], data["Username"], data["Location"], data["Joined_Date"]])

    driver.quit()

scrape_and_append_reviews("https://www.tripadvisor.in/Attraction_Review-g304554-d311661-Reviews-Colaba-Mumbai_Maharashtra.html", "COL")
# Out:
# Pagination element not found. Reached the last page.

# %%
import sys
import csv
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import time
import multiprocessing
from scrapper import scrape_and_append_reviews

code_to_name = {
    "GWOI": "Gateway Of India",
    "MD": "Marine Drive",
    "SHSI" : "Shree Siddhivinayak",
    "BWS" : "Bandra-Worli Sea Link",
    "CST" : "Chhatrapati Shivaji Terminus",
    "KZM" : "KidZania Mumbai",
    "MBGM" : "Mani Bhavan Gandhi Museum",
    "COL" : "Colaba",
    "ELC" : "Elephanta Caves",
    "NP" : "Nariman Point",
    "GVP" : "Global Vipassana Pagoda",
    "KC" : "Kanheri Caves",
    "MMB" : "Mount Mary Basilica",
    "CSMVS" : "Chhatrapati Shivaji Maharaj Vastu Sangrahalaya",
    "EW" : "Essel World",
    "SSRGP" : "Sri Sri Radha Gopinath Temple",
    "JB" : "Juhu Beach"
}

code_to_url = {
    "GWOI" : "https://www.tripadvisor.in/Attraction_Review-g304554-d311667-Reviews-Gateway_of_India-Mumbai_Maharashtra.html",
    "MD" : "https://www.tripadvisor.in/Attraction_Review-g304554-d321437-Reviews-Marine_Drive-Mumbai_Maharashtra.html",
    "SHSI" : "https://www.tripadvisor.in/Attraction_Review-g304554-d622586-Reviews-Shree_Siddhivinayak-Mumbai_Maharashtra.html",
    "BWS" : "https://www.tripadvisor.in/Attraction_Review-g304554-d2704519-Reviews-Bandra_Worli_Sea_Link-Mumbai_Maharashtra.html",
    "CST" : "https://www.tripadvisor.in/Attraction_Review-g304554-d321412-Reviews-Chhatrapati_Shivaji_Terminus-Mumbai_Maharashtra.html",
    "KZM" : "https://www.tripadvisor.in/Attraction_Review-g304554-d4817230-Reviews-KidZania_Mumbai-Mumbai_Maharashtra.html",
    "MBGM" : "https://www.tripadvisor.in/Attraction_Review-g304554-d311674-Reviews-Mani_Bhavan_Gandhi_Museum-Mumbai_Maharashtra.html",
    "COL" : "https://www.tripadvisor.in/Attraction_Review-g304554-d311661-Reviews-Colaba-Mumbai_Maharashtra.html",
    "ELC" : "https://www.tripadvisor.in/AttractionProductReview-g304554-d19066869-Elephanta_Caves_Mumbai_Excursion-Mumbai_Maharashtra.html",
    "NP" : "https://www.tripadvisor.in/Attraction_Review-g304554-d3783379-Reviews-Nariman_Point-Mumbai_Maharashtra.html",
    "GVP" : "https://www.tripadvisor.in/Attraction_Review-g304554-d2514810-Reviews-Global_Vipassana_Pagoda-Mumbai_Maharashtra.html",
    "KC" : "https://www.tripadvisor.in/Attraction_Review-g304554-d1204502-Reviews-Kanheri_Caves-Mumbai_Maharashtra.html",
    "MMB" : "https://www.tripadvisor.in/Attraction_Review-g304554-d2638424-Reviews-Mount_Mary_Basilica-Mumbai_Maharashtra.html",
    "CSMVS" : "https://www.tripadvisor.in/Attraction_Review-g304554-d10071803-Reviews-Chhatrapati_Shivaji_Maharaj_Vastu_Sangrahalaya-Mumbai_Maharashtra.html",
    "EW" : "https://www.tripadvisor.in/Attraction_Review-g304554-d321430-Reviews-Essel_World-Mumbai_Maharashtra.html",
    "SSRGP" : "https://www.tripadvisor.in/Attraction_Review-g304554-d3207759-Reviews-Sri_Sri_Radha_Gopinath_Temple-Mumbai_Maharashtra.html",
    "JB" : "https://www.tripadvisor.in/Attraction_Review-g304554-d321424-Reviews-Juhu_Beach-Mumbai_Maharashtra.html"
}

list_of_destinations = ["GWOI", "SHSI", "CST"]
# list_of_destinations = ["GWOI", "MD", "SHSI", "BWS", "CST", "KZM", "MBGM", "COL", "ELC", "NP", "GVP", "KC", "MMB", "CSMVS", "EW", "SSRGP", "JB"]

if __name__ == "__main__":
    args_list = []

    for i in list_of_destinations:
        tup = (code_to_url[i], i)
        args_list.append(tup)

    processes = []
    for args in args_list:
        process = multiprocessing.Process(target=scrape_and_append_reviews, args=args)
        processes.append(process)
        process.start()

    for process in processes:
        process.join()
# Out:
# Process Process-3:
# Traceback (most recent call last):
#   File "/Users/vishnuudaiyar/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/vishnuudaiyar/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/vishnuudaiyar/Desktop/Projects/SET1/Codes/scrapper.py", line 53, in scrape_and_append_reviews
#     container = driver.find_elements("xpath","//div[contains(@data-automation, 'reviewCard')]")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/vishnuudaiyar/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py", line 778, in find_elements
#     return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/vishnuudaiyar/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py", line 354, in execute
#     self.error_handler.check_response(response)
#   File "/Users/vishnuudaiyar/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/errorhandler.py", line 229, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=129.0.6668.90)
# Stacktrace:
# 0   chromedriver                        0x0000000102914248 cxxbridge1$str$ptr + 1907280
# 1   chromedriver                        0x000000010290c730 cxxbridge1$str$ptr + 1875768
# 2   chromedriver                        0x0000000102520260 cxxbridge1$string$len + 89488
# 3   chromedriver                        0x00000001024fb728 core::str::slice_error_fail::hbaf5d05fe3921cd2 + 3776
# 4   chromedriver                        0x000000010258ae8c cxxbridge1$string$len + 526780
# 5   chromedriver                        0x000000010259e218 cxxbridge1$string$len + 605512
# 6   chromedriver                        0x000000010255912c cxxbridge1$string$len + 322652
# 7   chromedriver                        0x0000000102559d7c cxxbridge1$string$len + 325804
# 8   chromedriver                        0x00000001028dc4d8 cxxbridge1$str$ptr + 1678560
# 9   chromedriver                        0x00000001028e0e40 cxxbridge1$str$ptr + 1697352
# 10  chromedriver                        0x00000001028c15ec cxxbridge1$str$ptr + 1568244
# 11  chromedriver                        0x00000001028e1710 cxxbridge1$str$ptr + 1699608
# 12  chromedriver                        0x00000001028b2b90 cxxbridge1$str$ptr + 1508248
# 13  chromedriver                        0x00000001028fd828 cxxbridge1$str$ptr + 1814576
# 14  chromedriver                        0x00000001028fd980 cxxbridge1$str$ptr + 1814920
# 15  chromedriver                        0x000000010290c3d0 cxxbridge1$str$ptr + 1874904
# 16  libsystem_pthread.dylib             0x00000001955cb2e4 _pthread_start + 136
# 17  libsystem_pthread.dylib             0x00000001955c60fc thread_start + 8
# Pagination element not found. Reached the last page.
# Process Process-1:
# Traceback (most recent call last):
#   File "/Users/vishnuudaiyar/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/vishnuudaiyar/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/vishnuudaiyar/Desktop/Projects/SET1/Codes/scrapper.py", line 53, in scrape_and_append_reviews
#     container = driver.find_elements("xpath","//div[contains(@data-automation, 'reviewCard')]")
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/vishnuudaiyar/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py", line 778, in find_elements
#     return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/vishnuudaiyar/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py", line 354, in execute
#     self.error_handler.check_response(response)
#   File "/Users/vishnuudaiyar/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/errorhandler.py", line 229, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=129.0.6668.90)
# Stacktrace:
# 0   chromedriver                        0x00000001049dc248 cxxbridge1$str$ptr + 1907280
# 1   chromedriver                        0x00000001049d4730 cxxbridge1$str$ptr + 1875768
# 2   chromedriver                        0x00000001045e8260 cxxbridge1$string$len + 89488
# 3   chromedriver                        0x00000001045c3728 core::str::slice_error_fail::hbaf5d05fe3921cd2 + 3776
# 4   chromedriver                        0x0000000104652e8c cxxbridge1$string$len + 526780
# 5   chromedriver                        0x0000000104666218 cxxbridge1$string$len + 605512
# 6   chromedriver                        0x000000010462112c cxxbridge1$string$len + 322652
# 7   chromedriver                        0x0000000104621d7c cxxbridge1$string$len + 325804
# 8   chromedriver                        0x00000001049a44d8 cxxbridge1$str$ptr + 1678560
# 9   chromedriver                        0x00000001049a8e40 cxxbridge1$str$ptr + 1697352
# 10  chromedriver                        0x00000001049895ec cxxbridge1$str$ptr + 1568244
# 11  chromedriver                        0x00000001049a9710 cxxbridge1$str$ptr + 1699608
# 12  chromedriver                        0x000000010497ab90 cxxbridge1$str$ptr + 1508248
# 13  chromedriver                        0x00000001049c5828 cxxbridge1$str$ptr + 1814576
# 14  chromedriver                        0x00000001049c5980 cxxbridge1$str$ptr + 1814920
# 15  chromedriver                        0x00000001049d43d0 cxxbridge1$str$ptr + 1874904
# 16  libsystem_pthread.dylib             0x00000001955cb2e4 _pthread_start + 136
# 17  libsystem_pthread.dylib             0x00000001955c60fc thread_start + 8
